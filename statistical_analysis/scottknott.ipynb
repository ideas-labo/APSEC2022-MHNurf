# %%
install.packages("ScottKnottESD")
library(ScottKnottESD)

# %%
sorted_result <- read.csv(file = 'sorted_tensorflow.csv')
# sorted_result <- read.csv(file = 'sorted_pytorch.csv')
# sorted_result <- read.csv(file = 'sorted_keras.csv')
# sorted_result <- read.csv(file = 'sorted_mxnet.csv')
# sorted_result <- read.csv(file = 'sorted_caffe.csv')

sorted_result <- sorted_result[c(2:ncol(sorted_result))]

# # Using Non-Parametric ScottKnott ESD test
sk <- sk_esd(sorted_result, version="np")
sk
